# %%
import pandas as pd
import numpy as np

# Load dataset
df = pd.read_csv("./datasets/bike_data.csv", index_col=0)

# %%
# Copy this to other notebooks to get the train and test data
def load_train_test():
    train_df = pd.read_csv("./datasets/bike_train.csv", index_col=0)
    test_df = pd.read_csv("./datasets/bike_test.csv", index_col=0)
    X_train = train_df.drop("Count", axis=1).values
    y_train = train_df["Count"]
    X_test = test_df.drop("Count", axis=1).values
    y_test = test_df["Count"]
    return (X_train, X_test, y_train, y_test)

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = load_train_test()

# %% [markdown]
# ## Random Forest Models

# %% [markdown]
# ### Random Forest Basic

# %%
from sklearn.metrics import r2_score

def get_best_split(x, y, f_idxs):
    bfeature = None # best feature
    bthreshold = None # best threshold
    brss = float('inf') # best residual sum of squares
    for f in f_idxs: # go through each feature
        tholds = np.unique(x[:,f]) # get unique x-cutoff values (thresholds)
        tholds.sort()
        for t in tholds[1:]: # skip first, because we want a split of at least one sample
            yl_idx = x[:,f] < t # idx of those samples (of given feature) that are below threshold
            yl = y[yl_idx] # target region below threshold
            yr = y[~yl_idx] # target region above threshold
            lrss = ((yl - yl.mean())**2).sum() # region specific residual sum of squares (left)
            rrss = ((yr - yr.mean())**2).sum() # region specific residual sum of squares (right)
            trss = lrss + rrss # overall loss
            if trss < brss: # best split so far, record parameters
                brss = trss
                bthreshold = t
                bfeature = f
    return {'f': bfeature, 'thold': bthreshold} # tree node with best feature and x cutoff


def split(x, y, depth, max_features):
    if depth == 1 or len(x) < 2:
        return {'prediction': np.mean(y)}

    f_idxs = np.random.choice(x.shape[1], max_features, replace=False) # pick random features
    splitnode = get_best_split(x, y, f_idxs) # get the best split
    if splitnode['f'] == None or splitnode['thold'] == None: # if leaf node, return mean of remaining y values
        return {'prediction': np.mean(y)}
    left_ix = x[:,splitnode['f']] < splitnode['thold'] # x values below cutoff
    splitnode['left'] = split(x[left_ix], y[left_ix], depth-1, max_features)
    splitnode['right'] = split(x[~left_ix], y[~left_ix], depth-1, max_features)
    return splitnode

def predict_val(xval, rules):
    if 'prediction' in rules.keys():
        return rules['prediction'] # leaf node
    feature, thold = rules['f'], rules['thold']
    if xval[feature] < thold:
        return predict_val(xval, rules['left']) # search left tree
    else:
        return predict_val(xval, rules['right']) # search right tree

def _predict(samples, rules):
    return np.array([predict_val(sample, rules) for sample in samples]) #predict vector

class RegressionTree:
    def __init__(self, max_depth, max_features=None):
        self.max_depth = max_depth
        self.max_features = max_features
        self.rules = None

    def fit(self, x, y):
        self.rules = split(x, y, 0, self.max_depth)
        return self

    def predict(self, x):
        return _predict(x, self.rules)

    def evaluate(self, x, y):
        return r2_score(self.predict(x), y)

class RandomForest:
    def __init__(self, max_depth, max_features=None, n_trees=100, sample_sz=1.0):
        self.max_depth = max_depth
        self.n_trees = n_trees
        self.max_features = max_features
        self.sample_sz = sample_sz
        self.trees = []
        for i in range(self.n_trees):
            self.trees.append(RegressionTree(max_depth=self.max_depth, max_features=self.max_features))

    def fit(self, x, y):
        for i in range(self.n_trees):
            sample_idx = np.random.choice(len(x), int(len(x)*self.sample_sz), replace=False)
            self.trees[i].fit(x[sample_idx], y[sample_idx])
        return self

    def predict(self, x):
        vals = np.zeros((self.n_trees, len(x)))
        for i in range(self.n_trees):
            vals[i] = self.trees[i].predict(x)
        return vals.mean(axis=0)

    def evaluate(self, x, y):
        return r2_score(self.predict(x), y)


LR = RandomForest(max_depth=15, max_features=13, sample_sz=0.55)

reg = LR.fit(X_train,y_train.values)
y_pred = LR.predict(X_test)
print("R2 score for random forest: ", r2_score(y_test.values, y_pred))
# Out:
# R2 score for random forest:  0.9131220312573133

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
N = 50

plt.plot(list(y_test[:N]), label="y-test")
plt.plot(list(y_pred[:N]), label="y_pred")
plt.legend()
plt.show()

# %% [markdown]
# ### Random Forest Variations

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV

param_grid = {  
            'max_features': range(1,22, 4),
            'ccp_alpha': np.linspace(0, 0.04, 5)
} 
grid = GridSearchCV(RandomForestRegressor(), param_grid, verbose=3)
grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)
print("R2 score for random forest (with grid search): ", r2_score(y_test, y_pred))
# Out:
# 0, max_features=9 ...................................
# [CV] ....... ccp_alpha=0.0, max_features=9, score=0.902, total=   1.2s
# [CV] ccp_alpha=0.0, max_features=9 ...................................
# [CV] ....... ccp_alpha=0.0, max_features=9, score=0.920, total=   1.2s
# [CV] ccp_alpha=0.0, max_features=9 ...................................
# [CV] ....... ccp_alpha=0.0, max_features=9, score=0.915, total=   1.2s
# [CV] ccp_alpha=0.0, max_features=9 ...................................
# [CV] ....... ccp_alpha=0.0, max_features=9, score=0.906, total=   1.2s
# [CV] ccp_alpha=0.0, max_features=9 ...................................
# [CV] ....... ccp_alpha=0.0, max_features=9, score=0.911, total=   1.2s
# [CV] ccp_alpha=0.0, max_features=13 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=13, score=0.910, total=   1.5s
# [CV] ccp_alpha=0.0, max_features=13 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=13, score=0.919, total=   1.5s
# [CV] ccp_alpha=0.0, max_features=13 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=13, score=0.920, total=   1.6s
# [CV] ccp_alpha=0.0, max_features=13 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=13, score=0.914, total=   1.5s
# [CV] ccp_alpha=0.0, max_features=13 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=13, score=0.916, total=   1.4s
# [CV] ccp_alpha=0.0, max_features=17 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=17, score=0.911, total=   1.8s
# [CV] ccp_alpha=0.0, max_features=17 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=17, score=0.918, total=   1.7s
# [CV] ccp_alpha=0.0, max_features=17 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=17, score=0.916, total=   1.7s
# [CV] ccp_alpha=0.0, max_features=17 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=17, score=0.918, total=   1.7s
# [CV] ccp_alpha=0.0, max_features=17 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=17, score=0.915, total=   1.7s
# [CV] ccp_alpha=0.0, max_features=21 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=21, score=0.915, total=   2.0s
# [CV] ccp_alpha=0.0, max_features=21 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=21, score=0.915, total=   2.0s
# [CV] ccp_alpha=0.0, max_features=21 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=21, score=0.915, total=   2.0s
# [CV] ccp_alpha=0.0, max_features=21 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=21, score=0.916, total=   2.0s
# [CV] ccp_alpha=0.0, max_features=21 ..................................
# [CV] ...... ccp_alpha=0.0, max_features=21, score=0.917, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=1, score=0.799, total=   1.0s
# [CV] ccp_alpha=0.01, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=1, score=0.841, total=   1.0s
# [CV] ccp_alpha=0.01, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=1, score=0.824, total=   1.0s
# [CV] ccp_alpha=0.01, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=1, score=0.837, total=   1.0s
# [CV] ccp_alpha=0.01, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=1, score=0.828, total=   1.0s
# [CV] ccp_alpha=0.01, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=5, score=0.874, total=   1.3s
# [CV] ccp_alpha=0.01, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=5, score=0.895, total=   1.4s
# [CV] ccp_alpha=0.01, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=5, score=0.896, total=   1.4s
# [CV] ccp_alpha=0.01, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=5, score=0.889, total=   1.4s
# [CV] ccp_alpha=0.01, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=5, score=0.891, total=   1.4s
# [CV] ccp_alpha=0.01, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=9, score=0.900, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=9, score=0.915, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=9, score=0.912, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=9, score=0.908, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.01, max_features=9, score=0.911, total=   2.0s
# [CV] ccp_alpha=0.01, max_features=13 .................................
# [CV] ..... ccp_alpha=0.01, max_features=13, score=0.910, total=   2.5s
# [CV] ccp_alpha=0.01, max_features=13 .................................
# [CV] ..... ccp_alpha=0.01, max_features=13, score=0.918, total=   2.5s
# [CV] ccp_alpha=0.01, max_features=13 .................................
# [CV] ..... ccp_alpha=0.01, max_features=13, score=0.918, total=   2.5s
# [CV] ccp_alpha=0.01, max_features=13 .................................
# [CV] ..... ccp_alpha=0.01, max_features=13, score=0.916, total=   2.5s
# [CV] ccp_alpha=0.01, max_features=13 .................................
# [CV] ..... ccp_alpha=0.01, max_features=13, score=0.917, total=   2.5s
# [CV] ccp_alpha=0.01, max_features=17 .................................
# [CV] ..... ccp_alpha=0.01, max_features=17, score=0.913, total=   2.9s
# [CV] ccp_alpha=0.01, max_features=17 .................................
# [CV] ..... ccp_alpha=0.01, max_features=17, score=0.915, total=   2.9s
# [CV] ccp_alpha=0.01, max_features=17 .................................
# [CV] ..... ccp_alpha=0.01, max_features=17, score=0.916, total=   3.0s
# [CV] ccp_alpha=0.01, max_features=17 .................................
# [CV] ..... ccp_alpha=0.01, max_features=17, score=0.916, total=   2.9s
# [CV] ccp_alpha=0.01, max_features=17 .................................
# [CV] ..... ccp_alpha=0.01, max_features=17, score=0.918, total=   2.9s
# [CV] ccp_alpha=0.01, max_features=21 .................................
# [CV] ..... ccp_alpha=0.01, max_features=21, score=0.911, total=   3.3s
# [CV] ccp_alpha=0.01, max_features=21 .................................
# [CV] ..... ccp_alpha=0.01, max_features=21, score=0.912, total=   3.3s
# [CV] ccp_alpha=0.01, max_features=21 .................................
# [CV] ..... ccp_alpha=0.01, max_features=21, score=0.916, total=   3.3s
# [CV] ccp_alpha=0.01, max_features=21 .................................
# [CV] ..... ccp_alpha=0.01, max_features=21, score=0.916, total=   3.3s
# [CV] ccp_alpha=0.01, max_features=21 .................................
# [CV] ..... ccp_alpha=0.01, max_features=21, score=0.918, total=   3.3s
# [CV] ccp_alpha=0.02, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=1, score=0.801, total=   1.1s
# [CV] ccp_alpha=0.02, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=1, score=0.841, total=   1.1s
# [CV] ccp_alpha=0.02, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=1, score=0.828, total=   1.1s
# [CV] ccp_alpha=0.02, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=1, score=0.839, total=   1.1s
# [CV] ccp_alpha=0.02, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=1, score=0.826, total=   1.1s
# [CV] ccp_alpha=0.02, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=5, score=0.873, total=   1.6s
# [CV] ccp_alpha=0.02, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=5, score=0.900, total=   1.6s
# [CV] ccp_alpha=0.02, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=5, score=0.898, total=   1.6s
# [CV] ccp_alpha=0.02, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=5, score=0.890, total=   1.6s
# [CV] ccp_alpha=0.02, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=5, score=0.893, total=   1.6s
# [CV] ccp_alpha=0.02, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=9, score=0.898, total=   2.2s
# [CV] ccp_alpha=0.02, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=9, score=0.916, total=   2.2s
# [CV] ccp_alpha=0.02, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=9, score=0.916, total=   2.2s
# [CV] ccp_alpha=0.02, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=9, score=0.909, total=   2.2s
# [CV] ccp_alpha=0.02, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.02, max_features=9, score=0.911, total=   2.2s
# [CV] ccp_alpha=0.02, max_features=13 .................................
# [CV] ..... ccp_alpha=0.02, max_features=13, score=0.909, total=   2.8s
# [CV] ccp_alpha=0.02, max_features=13 .................................
# [CV] ..... ccp_alpha=0.02, max_features=13, score=0.919, total=   2.8s
# [CV] ccp_alpha=0.02, max_features=13 .................................
# [CV] ..... ccp_alpha=0.02, max_features=13, score=0.921, total=   2.9s
# [CV] ccp_alpha=0.02, max_features=13 .................................
# [CV] ..... ccp_alpha=0.02, max_features=13, score=0.916, total=   3.0s
# [CV] ccp_alpha=0.02, max_features=13 .................................
# [CV] ..... ccp_alpha=0.02, max_features=13, score=0.916, total=   2.8s
# [CV] ccp_alpha=0.02, max_features=17 .................................
# [CV] ..... ccp_alpha=0.02, max_features=17, score=0.909, total=   3.2s
# [CV] ccp_alpha=0.02, max_features=17 .................................
# [CV] ..... ccp_alpha=0.02, max_features=17, score=0.918, total=   3.3s
# [CV] ccp_alpha=0.02, max_features=17 .................................
# [CV] ..... ccp_alpha=0.02, max_features=17, score=0.917, total=   3.2s
# [CV] ccp_alpha=0.02, max_features=17 .................................
# [CV] ..... ccp_alpha=0.02, max_features=17, score=0.916, total=   3.2s
# [CV] ccp_alpha=0.02, max_features=17 .................................
# [CV] ..... ccp_alpha=0.02, max_features=17, score=0.918, total=   3.2s
# [CV] ccp_alpha=0.02, max_features=21 .................................
# [CV] ..... ccp_alpha=0.02, max_features=21, score=0.911, total=   3.6s
# [CV] ccp_alpha=0.02, max_features=21 .................................
# [CV] ..... ccp_alpha=0.02, max_features=21, score=0.915, total=   3.6s
# [CV] ccp_alpha=0.02, max_features=21 .................................
# [CV] ..... ccp_alpha=0.02, max_features=21, score=0.917, total=   3.7s
# [CV] ccp_alpha=0.02, max_features=21 .................................
# [CV] ..... ccp_alpha=0.02, max_features=21, score=0.914, total=   3.7s
# [CV] ccp_alpha=0.02, max_features=21 .................................
# [CV] ..... ccp_alpha=0.02, max_features=21, score=0.917, total=   3.6s
# [CV] ccp_alpha=0.03, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=1, score=0.799, total=   1.2s
# [CV] ccp_alpha=0.03, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=1, score=0.842, total=   1.2s
# [CV] ccp_alpha=0.03, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=1, score=0.826, total=   1.2s
# [CV] ccp_alpha=0.03, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=1, score=0.840, total=   1.2s
# [CV] ccp_alpha=0.03, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=1, score=0.826, total=   1.2s
# [CV] ccp_alpha=0.03, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=5, score=0.875, total=   1.7s
# [CV] ccp_alpha=0.03, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=5, score=0.902, total=   1.7s
# [CV] ccp_alpha=0.03, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=5, score=0.895, total=   1.7s
# [CV] ccp_alpha=0.03, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=5, score=0.894, total=   1.7s
# [CV] ccp_alpha=0.03, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=5, score=0.891, total=   1.7s
# [CV] ccp_alpha=0.03, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=9, score=0.900, total=   2.4s
# [CV] ccp_alpha=0.03, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=9, score=0.916, total=   2.4s
# [CV] ccp_alpha=0.03, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=9, score=0.914, total=   2.4s
# [CV] ccp_alpha=0.03, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=9, score=0.909, total=   2.5s
# [CV] ccp_alpha=0.03, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.03, max_features=9, score=0.914, total=   2.6s
# [CV] ccp_alpha=0.03, max_features=13 .................................
# [CV] ..... ccp_alpha=0.03, max_features=13, score=0.910, total=   3.4s
# [CV] ccp_alpha=0.03, max_features=13 .................................
# [CV] ..... ccp_alpha=0.03, max_features=13, score=0.919, total=   3.2s
# [CV] ccp_alpha=0.03, max_features=13 .................................
# [CV] ..... ccp_alpha=0.03, max_features=13, score=0.918, total=   3.0s
# [CV] ccp_alpha=0.03, max_features=13 .................................
# [CV] ..... ccp_alpha=0.03, max_features=13, score=0.917, total=   3.1s
# [CV] ccp_alpha=0.03, max_features=13 .................................
# [CV] ..... ccp_alpha=0.03, max_features=13, score=0.915, total=   3.1s
# [CV] ccp_alpha=0.03, max_features=17 .................................
# [CV] ..... ccp_alpha=0.03, max_features=17, score=0.913, total=   3.6s
# [CV] ccp_alpha=0.03, max_features=17 .................................
# [CV] ..... ccp_alpha=0.03, max_features=17, score=0.916, total=   3.6s
# [CV] ccp_alpha=0.03, max_features=17 .................................
# [CV] ..... ccp_alpha=0.03, max_features=17, score=0.918, total=   3.7s
# [CV] ccp_alpha=0.03, max_features=17 .................................
# [CV] ..... ccp_alpha=0.03, max_features=17, score=0.918, total=   3.9s
# [CV] ccp_alpha=0.03, max_features=17 .................................
# [CV] ..... ccp_alpha=0.03, max_features=17, score=0.918, total=   3.6s
# [CV] ccp_alpha=0.03, max_features=21 .................................
# [CV] ..... ccp_alpha=0.03, max_features=21, score=0.912, total=   3.9s
# [CV] ccp_alpha=0.03, max_features=21 .................................
# [CV] ..... ccp_alpha=0.03, max_features=21, score=0.914, total=   3.9s
# [CV] ccp_alpha=0.03, max_features=21 .................................
# [CV] ..... ccp_alpha=0.03, max_features=21, score=0.916, total=   3.9s
# [CV] ccp_alpha=0.03, max_features=21 .................................
# [CV] ..... ccp_alpha=0.03, max_features=21, score=0.917, total=   4.0s
# [CV] ccp_alpha=0.03, max_features=21 .................................
# [CV] ..... ccp_alpha=0.03, max_features=21, score=0.915, total=   4.0s
# [CV] ccp_alpha=0.04, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=1, score=0.798, total=   1.2s
# [CV] ccp_alpha=0.04, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=1, score=0.840, total=   1.3s
# [CV] ccp_alpha=0.04, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=1, score=0.823, total=   1.2s
# [CV] ccp_alpha=0.04, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=1, score=0.835, total=   1.2s
# [CV] ccp_alpha=0.04, max_features=1 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=1, score=0.826, total=   1.2s
# [CV] ccp_alpha=0.04, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=5, score=0.869, total=   1.8s
# [CV] ccp_alpha=0.04, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=5, score=0.897, total=   1.8s
# [CV] ccp_alpha=0.04, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=5, score=0.893, total=   1.9s
# [CV] ccp_alpha=0.04, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=5, score=0.892, total=   1.8s
# [CV] ccp_alpha=0.04, max_features=5 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=5, score=0.888, total=   2.0s
# [CV] ccp_alpha=0.04, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=9, score=0.897, total=   2.5s
# [CV] ccp_alpha=0.04, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=9, score=0.914, total=   2.7s
# [CV] ccp_alpha=0.04, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=9, score=0.912, total=   2.7s
# [CV] ccp_alpha=0.04, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=9, score=0.910, total=   2.7s
# [CV] ccp_alpha=0.04, max_features=9 ..................................
# [CV] ...... ccp_alpha=0.04, max_features=9, score=0.910, total=   2.9s
# [CV] ccp_alpha=0.04, max_features=13 .................................
# [CV] ..... ccp_alpha=0.04, max_features=13, score=0.908, total=   3.3s
# [CV] ccp_alpha=0.04, max_features=13 .................................
# [CV] ..... ccp_alpha=0.04, max_features=13, score=0.920, total=   3.2s
# [CV] ccp_alpha=0.04, max_features=13 .................................
# [CV] ..... ccp_alpha=0.04, max_features=13, score=0.919, total=   3.2s
# [CV] ccp_alpha=0.04, max_features=13 .................................
# [CV] ..... ccp_alpha=0.04, max_features=13, score=0.915, total=   3.1s
# [CV] ccp_alpha=0.04, max_features=13 .................................
# [CV] ..... ccp_alpha=0.04, max_features=13, score=0.917, total=   3.2s
# [CV] ccp_alpha=0.04, max_features=17 .................................
# [CV] ..... ccp_alpha=0.04, max_features=17, score=0.913, total=   3.6s
# [CV] ccp_alpha=0.04, max_features=17 .................................
# [CV] ..... ccp_alpha=0.04, max_features=17, score=0.917, total=   3.7s
# [CV] ccp_alpha=0.04, max_features=17 .................................
# [CV] ..... ccp_alpha=0.04, max_features=17, score=0.915, total=   3.7s
# [CV] ccp_alpha=0.04, max_features=17 .................................
# [CV] ..... ccp_alpha=0.04, max_features=17, score=0.917, total=   3.7s
# [CV] ccp_alpha=0.04, max_features=17 .................................
# [CV] ..... ccp_alpha=0.04, max_features=17, score=0.917, total=   3.6s
# [CV] ccp_alpha=0.04, max_features=21 .................................
# [CV] ..... ccp_alpha=0.04, max_features=21, score=0.911, total=   4.1s
# [CV] ccp_alpha=0.04, max_features=21 .................................
# [CV] ..... ccp_alpha=0.04, max_features=21, score=0.916, total=   4.1s
# [CV] ccp_alpha=0.04, max_features=21 .................................
# [CV] ..... ccp_alpha=0.04, max_features=21, score=0.916, total=   4.1s
# [CV] ccp_alpha=0.04, max_features=21 .................................
# [CV] ..... ccp_alpha=0.04, max_features=21, score=0.916, total=   4.1s
# [CV] ccp_alpha=0.04, max_features=21 .................................
# [CV] ..... ccp_alpha=0.04, max_features=21, score=0.916, total=   4.1s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:  5.7min finished
# R2 score for random forest (with grid search):  0.9109653993253687

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
N = 50

plt.plot(list(y_test[:N]), label="y-test")
plt.plot(list(y_pred[:N]), label="y_pred")
plt.legend()
plt.show()

# %% [markdown]
# ## Model Persistence

# %%
from joblib import dump, load
dump(LR, './models/random_forest.joblib')
# Out:
# ['./models/random_forest.joblib']
